# %%
import pandas as pd
import seaborn as sns

# %%
import sys
sys.path.append('..')

# %%
from scripts import project_functions as pf

# %%
path = '../../data/raw/waterpotability.csv'

# %%
pf.load_and_process(path)
# Out:
#              pH  Hardness (mg/L)  Solids (ppm)  Chloramines (ppm)  \
# 0      8.316766       214.373394   22018.41744           8.059332
# 1      9.092223       181.101509   17978.98634           6.546600
# 2      5.584087       188.313324   28748.68774           7.544869
# 3     10.223862       248.071735   28749.71654           7.513408
# 4      8.635849       203.361523   13672.09176           4.563009
# ...         ...              ...           ...                ...
# 2006   8.989900       215.047358   15921.41202           6.297312
# 2007   6.702547       207.321086   17246.92035           7.708117
# 2008  11.491011        94.812545   37188.82602           9.263166
# 2009   6.069616       186.659040   26138.78019           7.747547
# 2010   4.668102       193.681736   47580.99160           7.166639
#
#       Sulfate (mg/L)  Conductivity (μS/cm)  Organic Carbon (ppm)  \
# 0         356.886136            363.266516             18.436525
# ...
